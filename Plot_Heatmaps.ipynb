# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from Plotter import *

# %%
#All bmp files of the following directory will be processed.
dirname_initial= '/home/maike/Dokumente/Private/ScienceArts/Birkl/dummyContainer'
#Name of directory where created pictures should be stored.
dirname_final = 'Colormaps_selection'  

#Choose a suitable color map: gist_earth_r | viridis | inferno | plasma   
colors = {'viridis': plt.cm.viridis, 'gist_earth': plt.cm.gist_earth, 'inferno': plt.cm.inferno, 'plasma': plt.cm.plasma}
#True for storing and False for not storing the pictures
save_boolean = True
resolution = 1000

# %%
for colorname, colorscheme in colors.items():
    plotArts(dirname_initial, folder_save=f'{dirname_final}/{colorname}', suffix_save=colorname, colormap=colorscheme, save=save_boolean, dpi=resolution)
